# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketbaghel9040-cyber/ai/blob/main/Basic_Hebb_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Input data
X = np.array([
    [1, 1],
    [1, -1],
    [-1, 1],
    [-1, -1]
])

# Target output
Y = np.array([1, -1, -1, 1])

# Initialize weights
w = np.zeros(2)
learning_rate = 1

print("Initial Weights:", w)

# Hebb Learning
for i in range(len(X)):
    w = w + learning_rate * X[i] * Y[i]
    print(f"After Sample {i+1}: {w}")

print("\nFinal Weights:", w)
# Out:
# Initial Weights: [0. 0.]
# After Sample 1: [1. 1.]
# After Sample 2: [0. 2.]
# After Sample 3: [1. 1.]
# After Sample 4: [0. 0.]
#
# Final Weights: [0. 0.]

# %%
import numpy as np

X = np.array([
    [1, 1],
    [1, -1],
    [-1, 1],
    [-1, -1]
])

Y = np.array([1, -1, -1, 1])

w = np.zeros(2)

# Training
for i in range(len(X)):
    w = w + X[i] * Y[i]

print("Final Weights:", w)

print("\nPrediction")
for x in X:
    net = np.dot(x, w)
    if net >= 0:
        output = 1
    else:
        output = -1

    print("Input:", x, "Output:", output)
# Out:
# Final Weights: [0. 0.]
#
# Prediction
# Input: [1 1] Output: 1
# Input: [ 1 -1] Output: 1
# Input: [-1  1] Output: 1
# Input: [-1 -1] Output: 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)

# Original graph
y = np.sin(x)

plt.plot(x, y)
plt.title("Original Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid()
plt.show()

# %%
# Add noise
noise = np.random.normal(0, 0.3, 100)

y_noisy = y + noise


plt.plot(x, y_noisy)
plt.title("Noisy Graph")
plt.grid()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(1,)),
    Dense(64, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse'
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(
    x,
    y_noisy,
    epochs=100,
    verbose=0
)

# %%
prediction = model.predict(x)

plt.figure(figsize=(8,5))

plt.scatter(x, y_noisy, label="Noisy Data")

plt.plot(
    x,
    prediction,
    label="AI Prediction"
)

plt.plot(
    x,
    y,
    label="Original"
)

plt.title("AI Manipulated Graph")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid()

plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
